# %% [markdown]
# <a href="https://colab.research.google.com/github/nowkoai/AzureOpenAIServicePracticalGuide-book/blob/main/section_1/01_stock_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 株価の取得

# %%
# 1. ライブラリのインストール（yfinanceがインストールされていない場合はコメントを外してください）
#!pip install yfinance

# 2. ライブラリのインポート
import yfinance as yf

# 3. データの取得
# 例: トヨタ自動車 (証券コード: 7203)
# 日本株は証券コードの末尾に ".T" をつけるのがルールです
data = yf.download("285A.T", period="1mo", auto_adjust=True) # 過去1ヶ月分

# 4. データの表示
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price         Close     High      Low     Open    Volume
# Ticker       285A.T   285A.T   285A.T   285A.T    285A.T
# Date
# 2025-12-16   8688.0   9157.0   8598.0   9052.0  36681500
# 2025-12-17   9300.0   9398.0   8632.0   8750.0  43905700
# 2025-12-18   9510.0   9564.0   9049.0   9130.0  41887500
# 2025-12-19   9340.0   9620.0   9130.0   9401.0  43344100
# 2025-12-22  10125.0  10330.0   9556.0   9600.0  31097800
# 2025-12-23   9952.0  10070.0   9716.0   9976.0  32701100
# 2025-12-24  10605.0  10700.0  10060.0  10160.0  26606100
# 2025-12-25  10795.0  11315.0  10470.0  10855.0  36070000
# 2025-12-26  11415.0  11450.0  10755.0  10815.0  31613200
# 2025-12-29  10675.0  11555.0  10615.0  11500.0  34828800
# 2025-12-30  10435.0  10705.0  10330.0  10400.0  24698700
# 2026-01-05  11350.0  11725.0  11205.0  11350.0  34412800
# 2026-01-06  11600.0  11600.0  10945.0  11500.0  33475000
# ...

# %% [markdown]
# # 株式の情報

# %%
# 1. Tickerオブジェクトを作成（ここではトヨタ自動車: 7203.T）
ticker = yf.Ticker("285A.T")

# 2. 情報を取得 (.info に辞書形式で入っています)
info = ticker.info
info
# Out:
# {'address1': '3-1-21, Shibaura',
#  'address2': 'Minato-ku',
#  'city': 'Tokyo',
#  'zip': '108-0023',
#  'country': 'Japan',
#  'website': 'https://www.kioxia-holdings.com',
#  'industry': 'Semiconductors',
#  'industryKey': 'semiconductors',
#  'industryDisp': 'Semiconductors',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %% [markdown]
# 情報を個別に取得することもできます。

# %%
print(f"【時価総額】 {info.get('marketCap'):,} 円")
print(f"【PER (株価収益率)】 {info.get('trailingPE')}")
print(f"【PBR (株価純資産倍率)】 {info.get('priceToBook')}")
print(f"【配当利回り】 {info.get('dividendYield', 0) * 100:.2f} %")

# %% [markdown]
# # 財務データ

# %% [markdown]
# 損益計算書

# %%
ticker.income_stmt

# %% [markdown]
# バランスシート

# %%
ticker.balance_sheet

# %% [markdown]
# キャッシュフロー

# %%
ticker.cashflow

# %% [markdown]
# # 銘柄の関連ニュース

# %%
ticker.news
